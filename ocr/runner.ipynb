# %%
import subprocess

command = [
    "python", "gpt_helper.py", ".",
    "--output", "gpt_summary.txt",
    "--allowed", ".py",
    "--disallowed_ext", ".log",  ".srt", ".vtt", ".txt",
    "--disallowed_folders", "__pycache__", ".venv",
    "--disallowed_files", "gpt_helper.py",
    "--max_kb", "300"
]

subprocess.run(command)

# python3 gpthelper.py . --output gpt_summary.txt --allowed .py --disallowed_ext .log .srt .vtt .txt --disallowed_folders __pycache__ .venv --disallowed_files gpt_helper.py --max_kb 300

# %%
import subprocess

subprocess.run(["python3", "custom_tree.py"])
